# %%
import torch as t
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import PIL
from PIL import Image
import json
from pathlib import Path
from typing import Union, Tuple, Callable, Optional
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import utils
import torch.nn as nn
from einops import rearrange, repeat

# %%
class BatchNorm2d(nn.Module):
    running_mean: t.Tensor         # shape: (num_features,)
    running_var: t.Tensor          # shape: (num_features,)
    num_batches_tracked: t.Tensor  # shape: ()

    def __init__(self, num_features: int, eps=1e-05, momentum=0.1):
        '''Like nn.BatchNorm2d with track_running_stats=True and affine=True.

        Name the learnable affine parameters `weight` and `bias` in that order.
        '''
        super().__init__()
        self.weight = t.nn.parameter.Parameter(t.ones(num_features))
        self.bias = t.nn.parameter.Parameter(t.zeros(num_features))
        self.eps=eps
        self.momentum=momentum
        self.num_features = num_features
        self.register_buffer("running_mean", t.zeros(num_features))
        self.register_buffer("running_var", t.ones(num_features))
        self.register_buffer("num_batches_tracked", t.tensor(0))

    def forward(self, x: t.Tensor) -> t.Tensor:
        '''Normalize each channel.

        x.shape = (batch channel height width)


        Compute the variance using `torch.var(x, unbiased=False)`
        Hint: you may also find it helpful to use the argument `keepdim`.

        x: shape (batch, channels, height, width)
        Return: shape (batch, channels, height, width)
        '''
        if self.train:
            mean = t.mean(x, dim=(0, 2, 3), keepdim=True) # reducing keeps channel dim. result is shape 1 everywhere except 'channels'
            var = t.var(x, dim=(0, 2, 3), unbiased=False, keepdim=True)
            self.running_mean = (1 - self.momentum) * mean.squeeze() + self.momentum * self.running_mean
            self.running_var = (1 - self.momentum) * var.squeeze() + self.momentum * self.running_var
            self.num_batches_tracked += 1
        else:
            mean = rearrange(self.running_mean, "channels -> 1 channels 1 1")
            var = rearrange(self.running_var, "channels -> 1 channels 1 1")

        weight = rearrange(self.weight, "channels -> 1 channels 1 1")
        bias = rearrange(self.bias, "channels -> 1 channels 1 1")

        return ((x - mean) / t.sqrt(var + self.eps)) * weight + bias

    def extra_repr(self) -> str:
        pass
arr = t.randn(1,2,3,3)
bn = BatchNorm2d(2)
tbn = t.nn.BatchNorm2d(2)

MAIN = True
    
if MAIN:
    utils.test_batchnorm2d_module(BatchNorm2d)
    utils.test_batchnorm2d_forward(BatchNorm2d)
    utils.test_batchnorm2d_running_mean(BatchNorm2d)
# Out:
# All tests in `test_batchnorm2d_module` passed!
# All tests in `test_batchnorm2d_forward` passed!
# All tests in `test_batchnorm2d_running_mean` passed!

# %%
class AveragePool(nn.Module):
    def forward(self, x: t.Tensor) -> t.Tensor:
        '''
        x: shape (batch, channels, height, width)
        Return: shape (batch, channels)
        '''
        return x.mean(dim=(2,3))

# %%
from torch.nn import Conv2d, ReLU, Sequential


class ResidualBlock(nn.Module):
    def __init__(self, in_feats: int, out_feats: int, first_stride=1):
        '''A single residual block with optional downsampling.

        For compatibility with the pretrained model, declare the left side branch first using a `Sequential`.

        If first_stride is > 1, this means the optional (conv + bn) should be present on the right branch. Declare it second using another `Sequential`.
        '''
        super().__init__()
        self.in_feats = in_feats
        self.out_feats = out_feats
        self.first_stride = first_stride
        self.left = Sequential(
            Conv2d(self.in_feats, self.out_feats, kernel_size=3, stride=self.first_stride, bias=False),
            BatchNorm2d(self.out_feats),
            ReLU(),
            Conv2d(self.out_feats, self.out_feats, kernel_size=3, padding=1, bias=False),
            BatchNorm2d(self.out_feats)
        )
        self.right = nn.Identity() if self.first_stride == 1 else Sequential(
            Conv2d(self.in_feats, self.out_feats, kernel_size=1, bias=False),
            BatchNorm2d(self.out_feats)
        )

    def forward(self, x: t.Tensor) -> t.Tensor:
        '''Compute the forward pass.

        x: shape (batch, in_feats, height, width)

        Return: shape (batch, out_feats, height / first_stride, width / first_stride)
        '''
        return t.relu(self.left(x) + self.right(x))

# %%
class BlockGroup(nn.Module):
    def __init__(self, n_blocks: int, in_feats: int, out_feats: int, first_stride=1):
        '''A single residual block with optional downsampling.

        For compatibility with the pretrained model, declare the left side branch first using a `Sequential`.

        If first_stride is > 1, this means the optional (conv + bn) should be present on the right branch. Declare it second using another `Sequential`.
        '''
        super().__init__()
        first = [ResidualBlock(in_feats, out_feats, first_stride)]
        rest = [ResidualBlock(out_feats, out_feats)] * (n_blocks - 1)
        self.model = nn.Sequential(*(first + rest))

        

    def forward(self, x: t.Tensor) -> t.Tensor:
        '''Compute the forward pass.

        x: shape (batch, in_feats, height, width)

        Return: shape (batch, out_feats, height / first_stride, width / first_stride)
        '''
        return self.model(x)

# %%
import torch.nn as nn

class ResNet34(nn.Module):
    def __init__(
        self,
        n_blocks_per_group=[3, 4, 6, 3],
        out_features_per_group=[64, 128, 256, 512],
        strides_per_group=[1, 2, 2, 2],
        n_classes=1000,
    ):
        super().__init__()
        self.n_blocks_per_group = n_blocks_per_group
        self.out_features_per_group = out_features_per_group
        self.strides_per_group = strides_per_group
        self.n_classes = n_classes

        first_in_features = 64
        in_features_per_group = [first_in_features] + out_features_per_group[:-1]

        blocks = [BlockGroup(n_blocks, in_feats, out_feats, first_stride) for n_blocks, in_feats, out_feats, first_stride in zip(
            n_blocks_per_group, in_features_per_group, out_features_per_group, strides_per_group
        )]

        self.model = Sequential(
            Conv2d(3, first_in_features, kernel_size=7, stride=2, padding=3, bias=False),
            BatchNorm2d(first_in_features),
            ReLU(),
            nn.MaxPool2d(3, 2),
            *blocks,
            AveragePool(),
            nn.Flatten(),
            nn.Linear(out_features_per_group[-1], 1000),
        )


    def forward(self, x: t.Tensor) -> t.Tensor:
        '''
        x: shape (batch, channels, height, width)

        Return: shape (batch, n_classes)
        '''
        return self.model(x)

pretrained = torchvision.models.resnet34(weights="DEFAULT")
myresnet = ResNet34()
# myresnet = copy_weights(myresnet, pretrained)

mydict = myresnet.state_dict()
pretraineddict = pretrained.state_dict()

import utils

utils.compare_my_resnet_to_pytorch(myresnet)
# Out:
#                                     their name       their shape  \
# 0                                 conv1.weight     (64, 3, 7, 7)
# 1                                   bn1.weight             (64,)
# 2                                     bn1.bias             (64,)
# 3                             bn1.running_mean             (64,)
# 4                              bn1.running_var             (64,)
# 5                      bn1.num_batches_tracked                ()
# 6                        layer1.0.conv1.weight    (64, 64, 3, 3)
# 7                          layer1.0.bn1.weight             (64,)
# 8                            layer1.0.bn1.bias             (64,)
# 9                    layer1.0.bn1.running_mean             (64,)
# 10                    layer1.0.bn1.running_var             (64,)
# 11            layer1.0.bn1.num_batches_tracked                ()
# 12                       layer1.0.conv2.weight    (64, 64, 3, 3)
# 13                         layer1.0.bn2.weight             (64,)
# 14                           layer1.0.bn2.bias             (64,)
# 15                   layer1.0.bn2.running_mean             (64,)
# 16                    layer1.0.bn2.running_var             (64,)
# 17            layer1.0.bn2.num_batches_tracked                ()
# 18                       layer1.1.conv1.weight    (64, 64, 3, 3)
# 19                         layer1.1.bn1.weight             (64,)
# 20                           layer1.1.bn1.bias             (64,)
# 21                   layer1.1.bn1.running_mean             (64,)
# 22                    layer1.1.bn1.running_var             (64,)
# 23            layer1.1.bn1.num_batches_tracked                ()
# 24                       layer1.1.conv2.weight    (64, 64, 3, 3)
# 25                         layer1.1.bn2.weight             (64,)
# 26                           layer1.1.bn2.bias             (64,)
# 27                   layer1.1.bn2.running_mean             (64,)
# 28                    layer1.1.bn2.running_var             (64,)
# 29            layer1.1.bn2.num_batches_tracked                ()
# 30                       layer1.2.conv1.weight    (64, 64, 3, 3)
# 31                         layer1.2.bn1.weight             (64,)
# 32                           layer1.2.bn1.bias             (64,)
# 33                   layer1.2.bn1.running_mean             (64,)
# 34                    layer1.2.bn1.running_var             (64,)
# 35            layer1.2.bn1.num_batches_tracked                ()
# 36                       layer1.2.conv2.weight    (64, 64, 3, 3)
# 37                         layer1.2.bn2.weight             (64,)
# 38                           layer1.2.bn2.bias             (64,)
# 39                   layer1.2.bn2.running_mean             (64,)
# 40                    layer1.2.bn2.running_var             (64,)
# 41            layer1.2.bn2.num_batches_tracked                ()
# 42                       layer2.0.conv1.weight   (128, 64, 3, 3)
# 43                         layer2.0.bn1.weight            (128,)
# 44                           layer2.0.bn1.bias            (128,)
# 45                   layer2.0.bn1.running_mean            (128,)
# 46                    layer2.0.bn1.running_var            (128,)
# 47            layer2.0.bn1.num_batches_tracked                ()
# 48                       layer2.0.conv2.weight  (128, 128, 3, 3)
# 49                         layer2.0.bn2.weight            (128,)
# 50                           layer2.0.bn2.bias            (128,)
# 51                   layer2.0.bn2.running_mean            (128,)
# 52                    layer2.0.bn2.running_var            (128,)
# 53            layer2.0.bn2.num_batches_tracked                ()
# 54                layer2.0.downsample.0.weight   (128, 64, 1, 1)
# 55                layer2.0.downsample.1.weight            (128,)
# 56                  layer2.0.downsample.1.bias            (128,)
# 57          layer2.0.downsample.1.running_mean            (128,)
# 58           layer2.0.downsample.1.running_var            (128,)
# 59   layer2.0.downsample.1.num_batches_tracked                ()
# 60                       layer2.1.conv1.weight  (128, 128, 3, 3)
# 61                         layer2.1.bn1.weight            (128,)
# 62                           layer2.1.bn1.bias            (128,)
# 63                   layer2.1.bn1.running_mean            (128,)
# 64                    layer2.1.bn1.running_var            (128,)
# 65            layer2.1.bn1.num_batches_tracked                ()
# 66                       layer2.1.conv2.weight  (128, 128, 3, 3)
# 67                         layer2.1.bn2.weight            (128,)
# 68                           layer2.1.bn2.bias            (128,)
# 69                   layer2.1.bn2.running_mean            (128,)
# 70                    layer2.1.bn2.running_var            (128,)
# 71            layer2.1.bn2.num_batches_tracked                ()
# 72                       layer2.2.conv1.weight  (128, 128, 3, 3)
# 73                         layer2.2.bn1.weight            (128,)
# 74                           layer2.2.bn1.bias            (128,)
# 75                   layer2.2.bn1.running_mean            (128,)
# 76                    layer2.2.bn1.running_var            (128,)
# 77            layer2.2.bn1.num_batches_tracked                ()
# 78                       layer2.2.conv2.weight  (128, 128, 3, 3)
# 79                         layer2.2.bn2.weight            (128,)
# 80                           layer2.2.bn2.bias            (128,)
# 81                   layer2.2.bn2.running_mean            (128,)
# 82                    layer2.2.bn2.running_var            (128,)
# 83            layer2.2.bn2.num_batches_tracked                ()
# 84                       layer2.3.conv1.weight  (128, 128, 3, 3)
# 85                         layer2.3.bn1.weight            (128,)
# 86                           layer2.3.bn1.bias            (128,)
# 87                   layer2.3.bn1.running_mean            (128,)
# 88                    layer2.3.bn1.running_var            (128,)
# 89            layer2.3.bn1.num_batches_tracked                ()
# 90                       layer2.3.conv2.weight  (128, 128, 3, 3)
# 91                         layer2.3.bn2.weight            (128,)
# 92                           layer2.3.bn2.bias            (128,)
# 93                   layer2.3.bn2.running_mean            (128,)
# 94                    layer2.3.bn2.running_var            (128,)
# 95            layer2.3.bn2.num_batches_tracked                ()
# 96                       layer3.0.conv1.weight  (256, 128, 3, 3)
# 97                         layer3.0.bn1.weight            (256,)
# 98                           layer3.0.bn1.bias            (256,)
# 99                   layer3.0.bn1.running_mean            (256,)
# 100                   layer3.0.bn1.running_var            (256,)
# 101           layer3.0.bn1.num_batches_tracked                ()
# 102                      layer3.0.conv2.weight  (256, 256, 3, 3)
# 103                        layer3.0.bn2.weight            (256,)
# 104                          layer3.0.bn2.bias            (256,)
# 105                  layer3.0.bn2.running_mean            (256,)
# 106                   layer3.0.bn2.running_var            (256,)
# 107           layer3.0.bn2.num_batches_tracked                ()
# 108               layer3.0.downsample.0.weight  (256, 128, 1, 1)
# 109               layer3.0.downsample.1.weight            (256,)
# 110                 layer3.0.downsample.1.bias            (256,)
# 111         layer3.0.downsample.1.running_mean            (256,)
# 112          layer3.0.downsample.1.running_var            (256,)
# 113  layer3.0.downsample.1.num_batches_tracked                ()
# 114                      layer3.1.conv1.weight  (256, 256, 3, 3)
# 115                        layer3.1.bn1.weight            (256,)
# 116                          layer3.1.bn1.bias            (256,)
# 117                  layer3.1.bn1.running_mean            (256,)
# 118                   layer3.1.bn1.running_var            (256,)
# 119           layer3.1.bn1.num_batches_tracked                ()
# 120                      layer3.1.conv2.weight  (256, 256, 3, 3)
# 121                        layer3.1.bn2.weight            (256,)
# 122                          layer3.1.bn2.bias            (256,)
# 123                  layer3.1.bn2.running_mean            (256,)
# 124                   layer3.1.bn2.running_var            (256,)
# 125           layer3.1.bn2.num_batches_tracked                ()
# 126                      layer3.2.conv1.weight  (256, 256, 3, 3)
# 127                        layer3.2.bn1.weight            (256,)
# 128                          layer3.2.bn1.bias            (256,)
# 129                  layer3.2.bn1.running_mean            (256,)
# 130                   layer3.2.bn1.running_var            (256,)
# 131           layer3.2.bn1.num_batches_tracked                ()
# 132                      layer3.2.conv2.weight  (256, 256, 3, 3)
# 133                        layer3.2.bn2.weight            (256,)
# 134                          layer3.2.bn2.bias            (256,)
# 135                  layer3.2.bn2.running_mean            (256,)
# 136                   layer3.2.bn2.running_var            (256,)
# 137           layer3.2.bn2.num_batches_tracked                ()
# 138                      layer3.3.conv1.weight  (256, 256, 3, 3)
# 139                        layer3.3.bn1.weight            (256,)
# 140                          layer3.3.bn1.bias            (256,)
# 141                  layer3.3.bn1.running_mean            (256,)
# 142                   layer3.3.bn1.running_var            (256,)
# 143           layer3.3.bn1.num_batches_tracked                ()
# 144                      layer3.3.conv2.weight  (256, 256, 3, 3)
# 145                        layer3.3.bn2.weight            (256,)
# 146                          layer3.3.bn2.bias            (256,)
# 147                  layer3.3.bn2.running_mean            (256,)
# 148                   layer3.3.bn2.running_var            (256,)
# 149           layer3.3.bn2.num_batches_tracked                ()
# 150                      layer3.4.conv1.weight  (256, 256, 3, 3)
# 151                        layer3.4.bn1.weight            (256,)
# 152                          layer3.4.bn1.bias            (256,)
# 153                  layer3.4.bn1.running_mean            (256,)
# 154                   layer3.4.bn1.running_var            (256,)
# 155           layer3.4.bn1.num_batches_tracked                ()
# 156                      layer3.4.conv2.weight  (256, 256, 3, 3)
# 157                        layer3.4.bn2.weight            (256,)
# 158                          layer3.4.bn2.bias            (256,)
# 159                  layer3.4.bn2.running_mean            (256,)
# 160                   layer3.4.bn2.running_var            (256,)
# 161           layer3.4.bn2.num_batches_tracked                ()
# 162                      layer3.5.conv1.weight  (256, 256, 3, 3)
# 163                        layer3.5.bn1.weight            (256,)
# 164                          layer3.5.bn1.bias            (256,)
# 165                  layer3.5.bn1.running_mean            (256,)
# 166                   layer3.5.bn1.running_var            (256,)
# 167           layer3.5.bn1.num_batches_tracked                ()
# 168                      layer3.5.conv2.weight  (256, 256, 3, 3)
# 169                        layer3.5.bn2.weight            (256,)
# 170                          layer3.5.bn2.bias            (256,)
# 171                  layer3.5.bn2.running_mean            (256,)
# 172                   layer3.5.bn2.running_var            (256,)
# 173           layer3.5.bn2.num_batches_tracked                ()
# 174                      layer4.0.conv1.weight  (512, 256, 3, 3)
# 175                        layer4.0.bn1.weight            (512,)
# 176                          layer4.0.bn1.bias            (512,)
# 177                  layer4.0.bn1.running_mean            (512,)
# 178                   layer4.0.bn1.running_var            (512,)
# 179           layer4.0.bn1.num_batches_tracked                ()
# 180                      layer4.0.conv2.weight  (512, 512, 3, 3)
# 181                        layer4.0.bn2.weight            (512,)
# 182                          layer4.0.bn2.bias            (512,)
# 183                  layer4.0.bn2.running_mean            (512,)
# 184                   layer4.0.bn2.running_var            (512,)
# 185           layer4.0.bn2.num_batches_tracked                ()
# 186               layer4.0.downsample.0.weight  (512, 256, 1, 1)
# 187               layer4.0.downsample.1.weight            (512,)
# 188                 layer4.0.downsample.1.bias            (512,)
# 189         layer4.0.downsample.1.running_mean            (512,)
# 190          layer4.0.downsample.1.running_var            (512,)
# 191  layer4.0.downsample.1.num_batches_tracked                ()
# 192                      layer4.1.conv1.weight  (512, 512, 3, 3)
# 193                        layer4.1.bn1.weight            (512,)
# 194                          layer4.1.bn1.bias            (512,)
# 195                  layer4.1.bn1.running_mean            (512,)
# 196                   layer4.1.bn1.running_var            (512,)
# 197           layer4.1.bn1.num_batches_tracked                ()
# 198                      layer4.1.conv2.weight  (512, 512, 3, 3)
# 199                        layer4.1.bn2.weight            (512,)
# 200                          layer4.1.bn2.bias            (512,)
# 201                  layer4.1.bn2.running_mean            (512,)
# 202                   layer4.1.bn2.running_var            (512,)
# 203           layer4.1.bn2.num_batches_tracked                ()
# 204                      layer4.2.conv1.weight  (512, 512, 3, 3)
# 205                        layer4.2.bn1.weight            (512,)
# 206                          layer4.2.bn1.bias            (512,)
# 207                  layer4.2.bn1.running_mean            (512,)
# 208                   layer4.2.bn1.running_var            (512,)
# 209           layer4.2.bn1.num_batches_tracked                ()
# 210                      layer4.2.conv2.weight  (512, 512, 3, 3)
# 211                        layer4.2.bn2.weight            (512,)
# 212                          layer4.2.bn2.bias            (512,)
# 213                  layer4.2.bn2.running_mean            (512,)
# 214                   layer4.2.bn2.running_var            (512,)
# 215           layer4.2.bn2.num_batches_tracked                ()
# 216                                  fc.weight       (1000, 512)
# 217                                    fc.bias           (1000,)
#
#                                        your name        your shape
# 0                                 model.0.weight     (64, 3, 7, 7)
# 1                                 model.1.weight             (64,)
# 2                                   model.1.bias             (64,)
# 3                           model.1.running_mean             (64,)
# 4                            model.1.running_var             (64,)
# 5                    model.1.num_batches_tracked                ()
# 6                  model.4.model.0.left.0.weight    (64, 64, 3, 3)
# 7                  model.4.model.0.left.1.weight             (64,)
# 8                    model.4.model.0.left.1.bias             (64,)
# 9            model.4.model.0.left.1.running_mean             (64,)
# 10            model.4.model.0.left.1.running_var             (64,)
# 11    model.4.model.0.left.1.num_batches_tracked                ()
# 12                 model.4.model.0.left.3.weight    (64, 64, 3, 3)
# 13                 model.4.model.0.left.4.weight             (64,)
# 14                   model.4.model.0.left.4.bias             (64,)
# 15           model.4.model.0.left.4.running_mean             (64,)
# 16            model.4.model.0.left.4.running_var             (64,)
# 17    model.4.model.0.left.4.num_batches_tracked                ()
# 18                 model.4.model.1.left.0.weight    (64, 64, 3, 3)
# 19                 model.4.model.1.left.1.weight             (64,)
# 20                   model.4.model.1.left.1.bias             (64,)
# 21           model.4.model.1.left.1.running_mean             (64,)
# 22            model.4.model.1.left.1.running_var             (64,)
# 23    model.4.model.1.left.1.num_batches_tracked                ()
# 24                 model.4.model.1.left.3.weight    (64, 64, 3, 3)
# 25                 model.4.model.1.left.4.weight             (64,)
# 26                   model.4.model.1.left.4.bias             (64,)
# 27           model.4.model.1.left.4.running_mean             (64,)
# 28            model.4.model.1.left.4.running_var             (64,)
# 29    model.4.model.1.left.4.num_batches_tracked                ()
# 30                 model.4.model.2.left.0.weight    (64, 64, 3, 3)
# 31                 model.4.model.2.left.1.weight             (64,)
# 32                   model.4.model.2.left.1.bias             (64,)
# 33           model.4.model.2.left.1.running_mean             (64,)
# 34            model.4.model.2.left.1.running_var             (64,)
# 35    model.4.model.2.left.1.num_batches_tracked                ()
# 36                 model.4.model.2.left.3.weight    (64, 64, 3, 3)
# 37                 model.4.model.2.left.4.weight             (64,)
# 38                   model.4.model.2.left.4.bias             (64,)
# 39           model.4.model.2.left.4.running_mean             (64,)
# 40            model.4.model.2.left.4.running_var             (64,)
# 41    model.4.model.2.left.4.num_batches_tracked                ()
# 42                 model.5.model.0.left.0.weight   (128, 64, 3, 3)
# 43                 model.5.model.0.left.1.weight            (128,)
# 44                   model.5.model.0.left.1.bias            (128,)
# 45           model.5.model.0.left.1.running_mean            (128,)
# 46            model.5.model.0.left.1.running_var            (128,)
# 47    model.5.model.0.left.1.num_batches_tracked                ()
# 48                 model.5.model.0.left.3.weight  (128, 128, 3, 3)
# 49                 model.5.model.0.left.4.weight            (128,)
# 50                   model.5.model.0.left.4.bias            (128,)
# 51           model.5.model.0.left.4.running_mean            (128,)
# 52            model.5.model.0.left.4.running_var            (128,)
# 53    model.5.model.0.left.4.num_batches_tracked                ()
# 54                model.5.model.0.right.0.weight   (128, 64, 1, 1)
# 55                model.5.model.0.right.1.weight            (128,)
# 56                  model.5.model.0.right.1.bias            (128,)
# 57          model.5.model.0.right.1.running_mean            (128,)
# 58           model.5.model.0.right.1.running_var            (128,)
# 59   model.5.model.0.right.1.num_batches_tracked                ()
# 60                 model.5.model.1.left.0.weight  (128, 128, 3, 3)
# 61                 model.5.model.1.left.1.weight            (128,)
# 62                   model.5.model.1.left.1.bias            (128,)
# 63           model.5.model.1.left.1.running_mean            (128,)
# 64            model.5.model.1.left.1.running_var            (128,)
# 65    model.5.model.1.left.1.num_batches_tracked                ()
# 66                 model.5.model.1.left.3.weight  (128, 128, 3, 3)
# 67                 model.5.model.1.left.4.weight            (128,)
# 68                   model.5.model.1.left.4.bias            (128,)
# 69           model.5.model.1.left.4.running_mean            (128,)
# 70            model.5.model.1.left.4.running_var            (128,)
# 71    model.5.model.1.left.4.num_batches_tracked                ()
# 72                 model.5.model.2.left.0.weight  (128, 128, 3, 3)
# 73                 model.5.model.2.left.1.weight            (128,)
# 74                   model.5.model.2.left.1.bias            (128,)
# 75           model.5.model.2.left.1.running_mean            (128,)
# 76            model.5.model.2.left.1.running_var            (128,)
# 77    model.5.model.2.left.1.num_batches_tracked                ()
# 78                 model.5.model.2.left.3.weight  (128, 128, 3, 3)
# 79                 model.5.model.2.left.4.weight            (128,)
# 80                   model.5.model.2.left.4.bias            (128,)
# 81           model.5.model.2.left.4.running_mean            (128,)
# 82            model.5.model.2.left.4.running_var            (128,)
# 83    model.5.model.2.left.4.num_batches_tracked                ()
# 84                 model.5.model.3.left.0.weight  (128, 128, 3, 3)
# 85                 model.5.model.3.left.1.weight            (128,)
# 86                   model.5.model.3.left.1.bias            (128,)
# 87           model.5.model.3.left.1.running_mean            (128,)
# 88            model.5.model.3.left.1.running_var            (128,)
# 89    model.5.model.3.left.1.num_batches_tracked                ()
# 90                 model.5.model.3.left.3.weight  (128, 128, 3, 3)
# 91                 model.5.model.3.left.4.weight            (128,)
# 92                   model.5.model.3.left.4.bias            (128,)
# 93           model.5.model.3.left.4.running_mean            (128,)
# 94            model.5.model.3.left.4.running_var            (128,)
# 95    model.5.model.3.left.4.num_batches_tracked                ()
# 96                 model.6.model.0.left.0.weight  (256, 128, 3, 3)
# 97                 model.6.model.0.left.1.weight            (256,)
# 98                   model.6.model.0.left.1.bias            (256,)
# 99           model.6.model.0.left.1.running_mean            (256,)
# 100           model.6.model.0.left.1.running_var            (256,)
# 101   model.6.model.0.left.1.num_batches_tracked                ()
# 102                model.6.model.0.left.3.weight  (256, 256, 3, 3)
# 103                model.6.model.0.left.4.weight            (256,)
# 104                  model.6.model.0.left.4.bias            (256,)
# 105          model.6.model.0.left.4.running_mean            (256,)
# 106           model.6.model.0.left.4.running_var            (256,)
# 107   model.6.model.0.left.4.num_batches_tracked                ()
# 108               model.6.model.0.right.0.weight  (256, 128, 1, 1)
# 109               model.6.model.0.right.1.weight            (256,)
# 110                 model.6.model.0.right.1.bias            (256,)
# 111         model.6.model.0.right.1.running_mean            (256,)
# 112          model.6.model.0.right.1.running_var            (256,)
# 113  model.6.model.0.right.1.num_batches_tracked                ()
# 114                model.6.model.1.left.0.weight  (256, 256, 3, 3)
# 115                model.6.model.1.left.1.weight            (256,)
# 116                  model.6.model.1.left.1.bias            (256,)
# 117          model.6.model.1.left.1.running_mean            (256,)
# 118           model.6.model.1.left.1.running_var            (256,)
# 119   model.6.model.1.left.1.num_batches_tracked                ()
# 120                model.6.model.1.left.3.weight  (256, 256, 3, 3)
# 121                model.6.model.1.left.4.weight            (256,)
# 122                  model.6.model.1.left.4.bias            (256,)
# 123          model.6.model.1.left.4.running_mean            (256,)
# 124           model.6.model.1.left.4.running_var            (256,)
# 125   model.6.model.1.left.4.num_batches_tracked                ()
# 126                model.6.model.2.left.0.weight  (256, 256, 3, 3)
# 127                model.6.model.2.left.1.weight            (256,)
# 128                  model.6.model.2.left.1.bias            (256,)
# 129          model.6.model.2.left.1.running_mean            (256,)
# 130           model.6.model.2.left.1.running_var            (256,)
# 131   model.6.model.2.left.1.num_batches_tracked                ()
# 132                model.6.model.2.left.3.weight  (256, 256, 3, 3)
# 133                model.6.model.2.left.4.weight            (256,)
# 134                  model.6.model.2.left.4.bias            (256,)
# 135          model.6.model.2.left.4.running_mean            (256,)
# 136           model.6.model.2.left.4.running_var            (256,)
# 137   model.6.model.2.left.4.num_batches_tracked                ()
# 138                model.6.model.3.left.0.weight  (256, 256, 3, 3)
# 139                model.6.model.3.left.1.weight            (256,)
# 140                  model.6.model.3.left.1.bias            (256,)
# 141          model.6.model.3.left.1.running_mean            (256,)
# 142           model.6.model.3.left.1.running_var            (256,)
# 143   model.6.model.3.left.1.num_batches_tracked                ()
# 144                model.6.model.3.left.3.weight  (256, 256, 3, 3)
# 145                model.6.model.3.left.4.weight            (256,)
# 146                  model.6.model.3.left.4.bias            (256,)
# 147          model.6.model.3.left.4.running_mean            (256,)
# 148           model.6.model.3.left.4.running_var            (256,)
# 149   model.6.model.3.left.4.num_batches_tracked                ()
# 150                model.6.model.4.left.0.weight  (256, 256, 3, 3)
# 151                model.6.model.4.left.1.weight            (256,)
# 152                  model.6.model.4.left.1.bias            (256,)
# 153          model.6.model.4.left.1.running_mean            (256,)
# 154           model.6.model.4.left.1.running_var            (256,)
# 155   model.6.model.4.left.1.num_batches_tracked                ()
# 156                model.6.model.4.left.3.weight  (256, 256, 3, 3)
# 157                model.6.model.4.left.4.weight            (256,)
# 158                  model.6.model.4.left.4.bias            (256,)
# 159          model.6.model.4.left.4.running_mean            (256,)
# 160           model.6.model.4.left.4.running_var            (256,)
# 161   model.6.model.4.left.4.num_batches_tracked                ()
# 162                model.6.model.5.left.0.weight  (256, 256, 3, 3)
# 163                model.6.model.5.left.1.weight            (256,)
# 164                  model.6.model.5.left.1.bias            (256,)
# 165          model.6.model.5.left.1.running_mean            (256,)
# 166           model.6.model.5.left.1.running_var            (256,)
# 167   model.6.model.5.left.1.num_batches_tracked                ()
# 168                model.6.model.5.left.3.weight  (256, 256, 3, 3)
# 169                model.6.model.5.left.4.weight            (256,)
# 170                  model.6.model.5.left.4.bias            (256,)
# 171          model.6.model.5.left.4.running_mean            (256,)
# 172           model.6.model.5.left.4.running_var            (256,)
# 173   model.6.model.5.left.4.num_batches_tracked                ()
# 174                model.7.model.0.left.0.weight  (512, 256, 3, 3)
# 175                model.7.model.0.left.1.weight            (512,)
# 176                  model.7.model.0.left.1.bias            (512,)
# 177          model.7.model.0.left.1.running_mean            (512,)
# 178           model.7.model.0.left.1.running_var            (512,)
# 179   model.7.model.0.left.1.num_batches_tracked                ()
# 180                model.7.model.0.left.3.weight  (512, 512, 3, 3)
# 181                model.7.model.0.left.4.weight            (512,)
# 182                  model.7.model.0.left.4.bias            (512,)
# 183          model.7.model.0.left.4.running_mean            (512,)
# 184           model.7.model.0.left.4.running_var            (512,)
# 185   model.7.model.0.left.4.num_batches_tracked                ()
# 186               model.7.model.0.right.0.weight  (512, 256, 1, 1)
# 187               model.7.model.0.right.1.weight            (512,)
# 188                 model.7.model.0.right.1.bias            (512,)
# 189         model.7.model.0.right.1.running_mean            (512,)
# 190          model.7.model.0.right.1.running_var            (512,)
# 191  model.7.model.0.right.1.num_batches_tracked                ()
# 192                model.7.model.1.left.0.weight  (512, 512, 3, 3)
# 193                model.7.model.1.left.1.weight            (512,)
# 194                  model.7.model.1.left.1.bias            (512,)
# 195          model.7.model.1.left.1.running_mean            (512,)
# 196           model.7.model.1.left.1.running_var            (512,)
# 197   model.7.model.1.left.1.num_batches_tracked                ()
# 198                model.7.model.1.left.3.weight  (512, 512, 3, 3)
# 199                model.7.model.1.left.4.weight            (512,)
# 200                  model.7.model.1.left.4.bias            (512,)
# 201          model.7.model.1.left.4.running_mean            (512,)
# 202           model.7.model.1.left.4.running_var            (512,)
# 203   model.7.model.1.left.4.num_batches_tracked                ()
# 204                model.7.model.2.left.0.weight  (512, 512, 3, 3)
# 205                model.7.model.2.left.1.weight            (512,)
# 206                  model.7.model.2.left.1.bias            (512,)
# 207          model.7.model.2.left.1.running_mean            (512,)
# 208           model.7.model.2.left.1.running_var            (512,)
# 209   model.7.model.2.left.1.num_batches_tracked                ()
# 210                model.7.model.2.left.3.weight  (512, 512, 3, 3)
# 211                model.7.model.2.left.4.weight            (512,)
# 212                  model.7.model.2.left.4.bias            (512,)
# 213          model.7.model.2.left.4.running_mean            (512,)
# 214           model.7.model.2.left.4.running_var            (512,)
# 215   model.7.model.2.left.4.num_batches_tracked                ()
# 216                              model.10.weight       (1000, 512)
# 217                                model.10.bias           (1000,)

# %%
def copy_weights(myresnet: ResNet34, pretrained_resnet: torchvision.models.resnet.ResNet) -> ResNet34:
    '''Copy over the weights of `pretrained_resnet` to your resnet.'''

    mydict = myresnet.state_dict()
    pretraineddict = pretrained_resnet.state_dict()

    # Check the number of params/buffers is correct
    assert len(mydict) == len(pretraineddict), "Number of layers is wrong. Have you done the prev step correctly?"

    # Initialise an empty dictionary to store the correct key-value pairs
    state_dict_to_load = {}

    for (mykey, myvalue), (pretrainedkey, pretrainedvalue) in zip(mydict.items(), pretraineddict.items()):
        state_dict_to_load[mykey] = pretrainedvalue

    myresnet.load_state_dict(state_dict_to_load)

    return myresnet

pretrained = torchvision.models.resnet34(weights="DEFAULT")
myresnet = ResNet34()
myresnet = copy_weights(myresnet, pretrained)

# %%
print(myresnet)
print(pretrained)
# Out:
# ResNet34(
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d()
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): BlockGroup(
#       (model): Sequential(
#         (0): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (1): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (2): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#       )
#     )
#     (5): BlockGroup(
#       (model): Sequential(
#         (0): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d()
#           )
#         )
#         (1): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (2): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (3): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#       )
#     )
#     (6): BlockGroup(
#       (model): Sequential(
#         (0): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d()
#           )
#         )
#         (1): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (2): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (3): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (4): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (5): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#       )
#     )
#     (7): BlockGroup(
#       (model): Sequential(
#         (0): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d()
#           )
#         )
#         (1): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#         (2): ResidualBlock(
#           (left): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (1): BatchNorm2d()
#             (2): ReLU()
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d()
#           )
#           (right): Identity()
#         )
#       )
#     )
#     (8): AveragePool()
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=512, out_features=1000, bias=True)
#   )
# )
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# Out:
#                                     their name       their shape  \
# 0                                 conv1.weight     (64, 3, 7, 7)
# 1                                   bn1.weight             (64,)
# 2                                     bn1.bias             (64,)
# 3                             bn1.running_mean             (64,)
# 4                              bn1.running_var             (64,)
# 5                      bn1.num_batches_tracked                ()
# 6                        layer1.0.conv1.weight    (64, 64, 3, 3)
# 7                          layer1.0.bn1.weight             (64,)
# 8                            layer1.0.bn1.bias             (64,)
# 9                    layer1.0.bn1.running_mean             (64,)
# 10                    layer1.0.bn1.running_var             (64,)
# 11            layer1.0.bn1.num_batches_tracked                ()
# 12                       layer1.0.conv2.weight    (64, 64, 3, 3)
# 13                         layer1.0.bn2.weight             (64,)
# 14                           layer1.0.bn2.bias             (64,)
# 15                   layer1.0.bn2.running_mean             (64,)
# 16                    layer1.0.bn2.running_var             (64,)
# 17            layer1.0.bn2.num_batches_tracked                ()
# 18                       layer1.1.conv1.weight    (64, 64, 3, 3)
# 19                         layer1.1.bn1.weight             (64,)
# 20                           layer1.1.bn1.bias             (64,)
# 21                   layer1.1.bn1.running_mean             (64,)
# 22                    layer1.1.bn1.running_var             (64,)
# 23            layer1.1.bn1.num_batches_tracked                ()
# 24                       layer1.1.conv2.weight    (64, 64, 3, 3)
# 25                         layer1.1.bn2.weight             (64,)
# 26                           layer1.1.bn2.bias             (64,)
# 27                   layer1.1.bn2.running_mean             (64,)
# 28                    layer1.1.bn2.running_var             (64,)
# 29            layer1.1.bn2.num_batches_tracked                ()
# 30                       layer1.2.conv1.weight    (64, 64, 3, 3)
# 31                         layer1.2.bn1.weight             (64,)
# 32                           layer1.2.bn1.bias             (64,)
# 33                   layer1.2.bn1.running_mean             (64,)
# 34                    layer1.2.bn1.running_var             (64,)
# 35            layer1.2.bn1.num_batches_tracked                ()
# 36                       layer1.2.conv2.weight    (64, 64, 3, 3)
# 37                         layer1.2.bn2.weight             (64,)
# 38                           layer1.2.bn2.bias             (64,)
# 39                   layer1.2.bn2.running_mean             (64,)
# 40                    layer1.2.bn2.running_var             (64,)
# 41            layer1.2.bn2.num_batches_tracked                ()
# 42                       layer2.0.conv1.weight   (128, 64, 3, 3)
# 43                         layer2.0.bn1.weight            (128,)
# 44                           layer2.0.bn1.bias            (128,)
# 45                   layer2.0.bn1.running_mean            (128,)
# 46                    layer2.0.bn1.running_var            (128,)
# 47            layer2.0.bn1.num_batches_tracked                ()
# 48                       layer2.0.conv2.weight  (128, 128, 3, 3)
# 49                         layer2.0.bn2.weight            (128,)
# 50                           layer2.0.bn2.bias            (128,)
# 51                   layer2.0.bn2.running_mean            (128,)
# 52                    layer2.0.bn2.running_var            (128,)
# 53            layer2.0.bn2.num_batches_tracked                ()
# 54                layer2.0.downsample.0.weight   (128, 64, 1, 1)
# 55                layer2.0.downsample.1.weight            (128,)
# 56                  layer2.0.downsample.1.bias            (128,)
# 57          layer2.0.downsample.1.running_mean            (128,)
# 58           layer2.0.downsample.1.running_var            (128,)
# 59   layer2.0.downsample.1.num_batches_tracked                ()
# 60                       layer2.1.conv1.weight  (128, 128, 3, 3)
# 61                         layer2.1.bn1.weight            (128,)
# 62                           layer2.1.bn1.bias            (128,)
# 63                   layer2.1.bn1.running_mean            (128,)
# 64                    layer2.1.bn1.running_var            (128,)
# 65            layer2.1.bn1.num_batches_tracked                ()
# 66                       layer2.1.conv2.weight  (128, 128, 3, 3)
# 67                         layer2.1.bn2.weight            (128,)
# 68                           layer2.1.bn2.bias            (128,)
# 69                   layer2.1.bn2.running_mean            (128,)
# 70                    layer2.1.bn2.running_var            (128,)
# 71            layer2.1.bn2.num_batches_tracked                ()
# 72                       layer2.2.conv1.weight  (128, 128, 3, 3)
# 73                         layer2.2.bn1.weight            (128,)
# 74                           layer2.2.bn1.bias            (128,)
# 75                   layer2.2.bn1.running_mean            (128,)
# 76                    layer2.2.bn1.running_var            (128,)
# 77            layer2.2.bn1.num_batches_tracked                ()
# 78                       layer2.2.conv2.weight  (128, 128, 3, 3)
# 79                         layer2.2.bn2.weight            (128,)
# 80                           layer2.2.bn2.bias            (128,)
# 81                   layer2.2.bn2.running_mean            (128,)
# 82                    layer2.2.bn2.running_var            (128,)
# 83            layer2.2.bn2.num_batches_tracked                ()
# 84                       layer2.3.conv1.weight  (128, 128, 3, 3)
# 85                         layer2.3.bn1.weight            (128,)
# 86                           layer2.3.bn1.bias            (128,)
# 87                   layer2.3.bn1.running_mean            (128,)
# 88                    layer2.3.bn1.running_var            (128,)
# 89            layer2.3.bn1.num_batches_tracked                ()
# 90                       layer2.3.conv2.weight  (128, 128, 3, 3)
# 91                         layer2.3.bn2.weight            (128,)
# 92                           layer2.3.bn2.bias            (128,)
# 93                   layer2.3.bn2.running_mean            (128,)
# 94                    layer2.3.bn2.running_var            (128,)
# 95            layer2.3.bn2.num_batches_tracked                ()
# 96                       layer3.0.conv1.weight  (256, 128, 3, 3)
# 97                         layer3.0.bn1.weight            (256,)
# 98                           layer3.0.bn1.bias            (256,)
# 99                   layer3.0.bn1.running_mean            (256,)
# 100                   layer3.0.bn1.running_var            (256,)
# 101           layer3.0.bn1.num_batches_tracked                ()
# 102                      layer3.0.conv2.weight  (256, 256, 3, 3)
# 103                        layer3.0.bn2.weight            (256,)
# 104                          layer3.0.bn2.bias            (256,)
# 105                  layer3.0.bn2.running_mean            (256,)
# 106                   layer3.0.bn2.running_var            (256,)
# 107           layer3.0.bn2.num_batches_tracked                ()
# 108               layer3.0.downsample.0.weight  (256, 128, 1, 1)
# 109               layer3.0.downsample.1.weight            (256,)
# 110                 layer3.0.downsample.1.bias            (256,)
# 111         layer3.0.downsample.1.running_mean            (256,)
# 112          layer3.0.downsample.1.running_var            (256,)
# 113  layer3.0.downsample.1.num_batches_tracked                ()
# 114                      layer3.1.conv1.weight  (256, 256, 3, 3)
# 115                        layer3.1.bn1.weight            (256,)
# 116                          layer3.1.bn1.bias            (256,)
# 117                  layer3.1.bn1.running_mean            (256,)
# 118                   layer3.1.bn1.running_var            (256,)
# 119           layer3.1.bn1.num_batches_tracked                ()
# 120                      layer3.1.conv2.weight  (256, 256, 3, 3)
# 121                        layer3.1.bn2.weight            (256,)
# 122                          layer3.1.bn2.bias            (256,)
# 123                  layer3.1.bn2.running_mean            (256,)
# 124                   layer3.1.bn2.running_var            (256,)
# 125           layer3.1.bn2.num_batches_tracked                ()
# 126                      layer3.2.conv1.weight  (256, 256, 3, 3)
# 127                        layer3.2.bn1.weight            (256,)
# 128                          layer3.2.bn1.bias            (256,)
# 129                  layer3.2.bn1.running_mean            (256,)
# 130                   layer3.2.bn1.running_var            (256,)
# 131           layer3.2.bn1.num_batches_tracked                ()
# 132                      layer3.2.conv2.weight  (256, 256, 3, 3)
# 133                        layer3.2.bn2.weight            (256,)
# 134                          layer3.2.bn2.bias            (256,)
# 135                  layer3.2.bn2.running_mean            (256,)
# 136                   layer3.2.bn2.running_var            (256,)
# 137           layer3.2.bn2.num_batches_tracked                ()
# 138                      layer3.3.conv1.weight  (256, 256, 3, 3)
# 139                        layer3.3.bn1.weight            (256,)
# 140                          layer3.3.bn1.bias            (256,)
# 141                  layer3.3.bn1.running_mean            (256,)
# 142                   layer3.3.bn1.running_var            (256,)
# 143           layer3.3.bn1.num_batches_tracked                ()
# 144                      layer3.3.conv2.weight  (256, 256, 3, 3)
# 145                        layer3.3.bn2.weight            (256,)
# 146                          layer3.3.bn2.bias            (256,)
# 147                  layer3.3.bn2.running_mean            (256,)
# 148                   layer3.3.bn2.running_var            (256,)
# 149           layer3.3.bn2.num_batches_tracked                ()
# 150                      layer3.4.conv1.weight  (256, 256, 3, 3)
# 151                        layer3.4.bn1.weight            (256,)
# 152                          layer3.4.bn1.bias            (256,)
# 153                  layer3.4.bn1.running_mean            (256,)
# 154                   layer3.4.bn1.running_var            (256,)
# 155           layer3.4.bn1.num_batches_tracked                ()
# 156                      layer3.4.conv2.weight  (256, 256, 3, 3)
# 157                        layer3.4.bn2.weight            (256,)
# 158                          layer3.4.bn2.bias            (256,)
# 159                  layer3.4.bn2.running_mean            (256,)
# 160                   layer3.4.bn2.running_var            (256,)
# 161           layer3.4.bn2.num_batches_tracked                ()
# 162                      layer3.5.conv1.weight  (256, 256, 3, 3)
# 163                        layer3.5.bn1.weight            (256,)
# 164                          layer3.5.bn1.bias            (256,)
# 165                  layer3.5.bn1.running_mean            (256,)
# 166                   layer3.5.bn1.running_var            (256,)
# 167           layer3.5.bn1.num_batches_tracked                ()
# 168                      layer3.5.conv2.weight  (256, 256, 3, 3)
# 169                        layer3.5.bn2.weight            (256,)
# 170                          layer3.5.bn2.bias            (256,)
# 171                  layer3.5.bn2.running_mean            (256,)
# 172                   layer3.5.bn2.running_var            (256,)
# 173           layer3.5.bn2.num_batches_tracked                ()
# 174                      layer4.0.conv1.weight  (512, 256, 3, 3)
# 175                        layer4.0.bn1.weight            (512,)
# 176                          layer4.0.bn1.bias            (512,)
# 177                  layer4.0.bn1.running_mean            (512,)
# 178                   layer4.0.bn1.running_var            (512,)
# 179           layer4.0.bn1.num_batches_tracked                ()
# 180                      layer4.0.conv2.weight  (512, 512, 3, 3)
# 181                        layer4.0.bn2.weight            (512,)
# 182                          layer4.0.bn2.bias            (512,)
# 183                  layer4.0.bn2.running_mean            (512,)
# 184                   layer4.0.bn2.running_var            (512,)
# 185           layer4.0.bn2.num_batches_tracked                ()
# 186               layer4.0.downsample.0.weight  (512, 256, 1, 1)
# 187               layer4.0.downsample.1.weight            (512,)
# 188                 layer4.0.downsample.1.bias            (512,)
# 189         layer4.0.downsample.1.running_mean            (512,)
# 190          layer4.0.downsample.1.running_var            (512,)
# 191  layer4.0.downsample.1.num_batches_tracked                ()
# 192                      layer4.1.conv1.weight  (512, 512, 3, 3)
# 193                        layer4.1.bn1.weight            (512,)
# 194                          layer4.1.bn1.bias            (512,)
# 195                  layer4.1.bn1.running_mean            (512,)
# 196                   layer4.1.bn1.running_var            (512,)
# 197           layer4.1.bn1.num_batches_tracked                ()
# 198                      layer4.1.conv2.weight  (512, 512, 3, 3)
# 199                        layer4.1.bn2.weight            (512,)
# 200                          layer4.1.bn2.bias            (512,)
# 201                  layer4.1.bn2.running_mean            (512,)
# 202                   layer4.1.bn2.running_var            (512,)
# 203           layer4.1.bn2.num_batches_tracked                ()
# 204                      layer4.2.conv1.weight  (512, 512, 3, 3)
# 205                        layer4.2.bn1.weight            (512,)
# 206                          layer4.2.bn1.bias            (512,)
# 207                  layer4.2.bn1.running_mean            (512,)
# 208                   layer4.2.bn1.running_var            (512,)
# 209           layer4.2.bn1.num_batches_tracked                ()
# 210                      layer4.2.conv2.weight  (512, 512, 3, 3)
# 211                        layer4.2.bn2.weight            (512,)
# 212                          layer4.2.bn2.bias            (512,)
# 213                  layer4.2.bn2.running_mean            (512,)
# 214                   layer4.2.bn2.running_var            (512,)
# 215           layer4.2.bn2.num_batches_tracked                ()
# 216                                  fc.weight       (1000, 512)
# 217                                    fc.bias           (1000,)
#
#                                        your name        your shape
# 0                                 model.0.weight     (64, 3, 7, 7)
# 1                                   model.0.bias             (64,)
# 2                                 model.1.weight             (64,)
# 3                                   model.1.bias             (64,)
# 4                           model.1.running_mean             (64,)
# 5                            model.1.running_var             (64,)
# 6                    model.1.num_batches_tracked                ()
# 7                  model.4.model.0.left.0.weight    (64, 64, 3, 3)
# 8                    model.4.model.0.left.0.bias             (64,)
# 9                  model.4.model.0.left.1.weight             (64,)
# 10                   model.4.model.0.left.1.bias             (64,)
# 11           model.4.model.0.left.1.running_mean             (64,)
# 12            model.4.model.0.left.1.running_var             (64,)
# 13    model.4.model.0.left.1.num_batches_tracked                ()
# 14                 model.4.model.0.left.3.weight    (64, 64, 3, 3)
# 15                   model.4.model.0.left.3.bias             (64,)
# 16                 model.4.model.0.left.4.weight             (64,)
# 17                   model.4.model.0.left.4.bias             (64,)
# 18           model.4.model.0.left.4.running_mean             (64,)
# 19            model.4.model.0.left.4.running_var             (64,)
# 20    model.4.model.0.left.4.num_batches_tracked                ()
# 21                 model.4.model.1.left.0.weight    (64, 64, 3, 3)
# 22                   model.4.model.1.left.0.bias             (64,)
# 23                 model.4.model.1.left.1.weight             (64,)
# 24                   model.4.model.1.left.1.bias             (64,)
# 25           model.4.model.1.left.1.running_mean             (64,)
# 26            model.4.model.1.left.1.running_var             (64,)
# 27    model.4.model.1.left.1.num_batches_tracked                ()
# 28                 model.4.model.1.left.3.weight    (64, 64, 3, 3)
# 29                   model.4.model.1.left.3.bias             (64,)
# 30                 model.4.model.1.left.4.weight             (64,)
# 31                   model.4.model.1.left.4.bias             (64,)
# 32           model.4.model.1.left.4.running_mean             (64,)
# 33            model.4.model.1.left.4.running_var             (64,)
# 34    model.4.model.1.left.4.num_batches_tracked                ()
# 35                 model.4.model.2.left.0.weight    (64, 64, 3, 3)
# 36                   model.4.model.2.left.0.bias             (64,)
# 37                 model.4.model.2.left.1.weight             (64,)
# 38                   model.4.model.2.left.1.bias             (64,)
# 39           model.4.model.2.left.1.running_mean             (64,)
# 40            model.4.model.2.left.1.running_var             (64,)
# 41    model.4.model.2.left.1.num_batches_tracked                ()
# 42                 model.4.model.2.left.3.weight    (64, 64, 3, 3)
# 43                   model.4.model.2.left.3.bias             (64,)
# 44                 model.4.model.2.left.4.weight             (64,)
# 45                   model.4.model.2.left.4.bias             (64,)
# 46           model.4.model.2.left.4.running_mean             (64,)
# 47            model.4.model.2.left.4.running_var             (64,)
# 48    model.4.model.2.left.4.num_batches_tracked                ()
# 49                 model.5.model.0.left.0.weight   (128, 64, 3, 3)
# 50                   model.5.model.0.left.0.bias            (128,)
# 51                 model.5.model.0.left.1.weight            (128,)
# 52                   model.5.model.0.left.1.bias            (128,)
# 53           model.5.model.0.left.1.running_mean            (128,)
# 54            model.5.model.0.left.1.running_var            (128,)
# 55    model.5.model.0.left.1.num_batches_tracked                ()
# 56                 model.5.model.0.left.3.weight  (128, 128, 3, 3)
# 57                   model.5.model.0.left.3.bias            (128,)
# 58                 model.5.model.0.left.4.weight            (128,)
# 59                   model.5.model.0.left.4.bias            (128,)
# 60           model.5.model.0.left.4.running_mean            (128,)
# 61            model.5.model.0.left.4.running_var            (128,)
# 62    model.5.model.0.left.4.num_batches_tracked                ()
# 63                model.5.model.0.right.0.weight   (128, 64, 1, 1)
# 64                  model.5.model.0.right.0.bias            (128,)
# 65                model.5.model.0.right.1.weight            (128,)
# 66                  model.5.model.0.right.1.bias            (128,)
# 67          model.5.model.0.right.1.running_mean            (128,)
# 68           model.5.model.0.right.1.running_var            (128,)
# 69   model.5.model.0.right.1.num_batches_tracked                ()
# 70                 model.5.model.1.left.0.weight  (128, 128, 3, 3)
# 71                   model.5.model.1.left.0.bias            (128,)
# 72                 model.5.model.1.left.1.weight            (128,)
# 73                   model.5.model.1.left.1.bias            (128,)
# 74           model.5.model.1.left.1.running_mean            (128,)
# 75            model.5.model.1.left.1.running_var            (128,)
# 76    model.5.model.1.left.1.num_batches_tracked                ()
# 77                 model.5.model.1.left.3.weight  (128, 128, 3, 3)
# 78                   model.5.model.1.left.3.bias            (128,)
# 79                 model.5.model.1.left.4.weight            (128,)
# 80                   model.5.model.1.left.4.bias            (128,)
# 81           model.5.model.1.left.4.running_mean            (128,)
# 82            model.5.model.1.left.4.running_var            (128,)
# 83    model.5.model.1.left.4.num_batches_tracked                ()
# 84                 model.5.model.2.left.0.weight  (128, 128, 3, 3)
# 85                   model.5.model.2.left.0.bias            (128,)
# 86                 model.5.model.2.left.1.weight            (128,)
# 87                   model.5.model.2.left.1.bias            (128,)
# 88           model.5.model.2.left.1.running_mean            (128,)
# 89            model.5.model.2.left.1.running_var            (128,)
# 90    model.5.model.2.left.1.num_batches_tracked                ()
# 91                 model.5.model.2.left.3.weight  (128, 128, 3, 3)
# 92                   model.5.model.2.left.3.bias            (128,)
# 93                 model.5.model.2.left.4.weight            (128,)
# 94                   model.5.model.2.left.4.bias            (128,)
# 95           model.5.model.2.left.4.running_mean            (128,)
# 96            model.5.model.2.left.4.running_var            (128,)
# 97    model.5.model.2.left.4.num_batches_tracked                ()
# 98                 model.5.model.3.left.0.weight  (128, 128, 3, 3)
# 99                   model.5.model.3.left.0.bias            (128,)
# 100                model.5.model.3.left.1.weight            (128,)
# 101                  model.5.model.3.left.1.bias            (128,)
# 102          model.5.model.3.left.1.running_mean            (128,)
# 103           model.5.model.3.left.1.running_var            (128,)
# 104   model.5.model.3.left.1.num_batches_tracked                ()
# 105                model.5.model.3.left.3.weight  (128, 128, 3, 3)
# 106                  model.5.model.3.left.3.bias            (128,)
# 107                model.5.model.3.left.4.weight            (128,)
# 108                  model.5.model.3.left.4.bias            (128,)
# 109          model.5.model.3.left.4.running_mean            (128,)
# 110           model.5.model.3.left.4.running_var            (128,)
# 111   model.5.model.3.left.4.num_batches_tracked                ()
# 112                model.6.model.0.left.0.weight  (256, 128, 3, 3)
# 113                  model.6.model.0.left.0.bias            (256,)
# 114                model.6.model.0.left.1.weight            (256,)
# 115                  model.6.model.0.left.1.bias            (256,)
# 116          model.6.model.0.left.1.running_mean            (256,)
# 117           model.6.model.0.left.1.running_var            (256,)
# 118   model.6.model.0.left.1.num_batches_tracked                ()
# 119                model.6.model.0.left.3.weight  (256, 256, 3, 3)
# 120                  model.6.model.0.left.3.bias            (256,)
# 121                model.6.model.0.left.4.weight            (256,)
# 122                  model.6.model.0.left.4.bias            (256,)
# 123          model.6.model.0.left.4.running_mean            (256,)
# 124           model.6.model.0.left.4.running_var            (256,)
# 125   model.6.model.0.left.4.num_batches_tracked                ()
# 126               model.6.model.0.right.0.weight  (256, 128, 1, 1)
# 127                 model.6.model.0.right.0.bias            (256,)
# 128               model.6.model.0.right.1.weight            (256,)
# 129                 model.6.model.0.right.1.bias            (256,)
# 130         model.6.model.0.right.1.running_mean            (256,)
# 131          model.6.model.0.right.1.running_var            (256,)
# 132  model.6.model.0.right.1.num_batches_tracked                ()
# 133                model.6.model.1.left.0.weight  (256, 256, 3, 3)
# 134                  model.6.model.1.left.0.bias            (256,)
# 135                model.6.model.1.left.1.weight            (256,)
# 136                  model.6.model.1.left.1.bias            (256,)
# 137          model.6.model.1.left.1.running_mean            (256,)
# 138           model.6.model.1.left.1.running_var            (256,)
# 139   model.6.model.1.left.1.num_batches_tracked                ()
# 140                model.6.model.1.left.3.weight  (256, 256, 3, 3)
# 141                  model.6.model.1.left.3.bias            (256,)
# 142                model.6.model.1.left.4.weight            (256,)
# 143                  model.6.model.1.left.4.bias            (256,)
# 144          model.6.model.1.left.4.running_mean            (256,)
# 145           model.6.model.1.left.4.running_var            (256,)
# 146   model.6.model.1.left.4.num_batches_tracked                ()
# 147                model.6.model.2.left.0.weight  (256, 256, 3, 3)
# 148                  model.6.model.2.left.0.bias            (256,)
# 149                model.6.model.2.left.1.weight            (256,)
# 150                  model.6.model.2.left.1.bias            (256,)
# 151          model.6.model.2.left.1.running_mean            (256,)
# 152           model.6.model.2.left.1.running_var            (256,)
# 153   model.6.model.2.left.1.num_batches_tracked                ()
# 154                model.6.model.2.left.3.weight  (256, 256, 3, 3)
# 155                  model.6.model.2.left.3.bias            (256,)
# 156                model.6.model.2.left.4.weight            (256,)
# 157                  model.6.model.2.left.4.bias            (256,)
# 158          model.6.model.2.left.4.running_mean            (256,)
# 159           model.6.model.2.left.4.running_var            (256,)
# 160   model.6.model.2.left.4.num_batches_tracked                ()
# 161                model.6.model.3.left.0.weight  (256, 256, 3, 3)
# 162                  model.6.model.3.left.0.bias            (256,)
# 163                model.6.model.3.left.1.weight            (256,)
# 164                  model.6.model.3.left.1.bias            (256,)
# 165          model.6.model.3.left.1.running_mean            (256,)
# 166           model.6.model.3.left.1.running_var            (256,)
# 167   model.6.model.3.left.1.num_batches_tracked                ()
# 168                model.6.model.3.left.3.weight  (256, 256, 3, 3)
# 169                  model.6.model.3.left.3.bias            (256,)
# 170                model.6.model.3.left.4.weight            (256,)
# 171                  model.6.model.3.left.4.bias            (256,)
# 172          model.6.model.3.left.4.running_mean            (256,)
# 173           model.6.model.3.left.4.running_var            (256,)
# 174   model.6.model.3.left.4.num_batches_tracked                ()
# 175                model.6.model.4.left.0.weight  (256, 256, 3, 3)
# 176                  model.6.model.4.left.0.bias            (256,)
# 177                model.6.model.4.left.1.weight            (256,)
# 178                  model.6.model.4.left.1.bias            (256,)
# 179          model.6.model.4.left.1.running_mean            (256,)
# 180           model.6.model.4.left.1.running_var            (256,)
# 181   model.6.model.4.left.1.num_batches_tracked                ()
# 182                model.6.model.4.left.3.weight  (256, 256, 3, 3)
# 183                  model.6.model.4.left.3.bias            (256,)
# 184                model.6.model.4.left.4.weight            (256,)
# 185                  model.6.model.4.left.4.bias            (256,)
# 186          model.6.model.4.left.4.running_mean            (256,)
# 187           model.6.model.4.left.4.running_var            (256,)
# 188   model.6.model.4.left.4.num_batches_tracked                ()
# 189                model.6.model.5.left.0.weight  (256, 256, 3, 3)
# 190                  model.6.model.5.left.0.bias            (256,)
# 191                model.6.model.5.left.1.weight            (256,)
# 192                  model.6.model.5.left.1.bias            (256,)
# 193          model.6.model.5.left.1.running_mean            (256,)
# 194           model.6.model.5.left.1.running_var            (256,)
# 195   model.6.model.5.left.1.num_batches_tracked                ()
# 196                model.6.model.5.left.3.weight  (256, 256, 3, 3)
# 197                  model.6.model.5.left.3.bias            (256,)
# 198                model.6.model.5.left.4.weight            (256,)
# 199                  model.6.model.5.left.4.bias            (256,)
# 200          model.6.model.5.left.4.running_mean            (256,)
# 201           model.6.model.5.left.4.running_var            (256,)
# 202   model.6.model.5.left.4.num_batches_tracked                ()
# 203                model.7.model.0.left.0.weight  (512, 256, 3, 3)
# 204                  model.7.model.0.left.0.bias            (512,)
# 205                model.7.model.0.left.1.weight            (512,)
# 206                  model.7.model.0.left.1.bias            (512,)
# 207          model.7.model.0.left.1.running_mean            (512,)
# 208           model.7.model.0.left.1.running_var            (512,)
# 209   model.7.model.0.left.1.num_batches_tracked                ()
# 210                model.7.model.0.left.3.weight  (512, 512, 3, 3)
# 211                  model.7.model.0.left.3.bias            (512,)
# 212                model.7.model.0.left.4.weight            (512,)
# 213                  model.7.model.0.left.4.bias            (512,)
# 214          model.7.model.0.left.4.running_mean            (512,)
# 215           model.7.model.0.left.4.running_var            (512,)
# 216   model.7.model.0.left.4.num_batches_tracked                ()
# 217               model.7.model.0.right.0.weight  (512, 256, 1, 1)
